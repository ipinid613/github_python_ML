# %% [markdown]
# # 연산

# %%
a = 100
b = 200
print(a, "+" , b, "=", c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-22b951a384ea> in <cell line: 3>()
#       1 a = 100
#       2 b = 200
# ----> 3 print(a, "+" , b, "=", c)
#
# NameError: name 'c' is not defined

# %%
num1 = 100
num2 = 50
result = num1 + num2
print(result)
# Out:
# 150

# %%
result = num1 + 200
print(result)
# Out:
# 300

# %%
100 = num1 + num2
# Out:
#   File "<ipython-input-4-40646890c740>", line 1
#     100 = num1 + num2
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
num1 + num2 = result
# Out:
#   File "<ipython-input-5-43ddd4fa8ec0>", line 1
#     num1 + num2 = result
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
num1 = 100
num2 = 50
result = num1 - num2
print(num1, "-", num2, "=", result)
# Out:
# 100 - 50 = 50

# %%
num1 = 100
num2 = 50
result = num1 * num2
print(num1, "*", num2, "=", result)
# Out:
# 100 * 50 = 5000

# %%
num1 = 100
num2 = 200

result1 = num1 + num2
result2 = num1 - num2
result3 = num1 * num2
result4 = num1 / num2

print(num1, "+", num2, "=", result1)
print(num1, "-", num2, "=", result2)
print(num1, "*", num2, "=", result3)
print(num1, "/", num2, "=", result4)
# Out:
# 100 + 200 = 300
# 100 - 200 = -100
# 100 * 200 = 20000
# 100 / 200 = 0.5

# %%
num1 = int(input("num1의 값을 입력하세요."))
num2 = int(input("num2의 값을 입력하세요."))

result1 = num1 + num2
result2 = num1 - num2
result3 = num1 * num2
result4 = num1 / num2

print(num1, "+", num2, "=", result1)
print(num1, "-", num2, "=", result2)
print(num1, "*", num2, "=", result3)
print(num1, "/", num2, "=", result4)
# Out:
# num1의 값을 입력하세요.50
# num2의 값을 입력하세요.465
# 50 + 465 = 515
# 50 - 465 = -415
# 50 * 465 = 23250
# 50 / 465 = 0.10752688172043011

# %%
str1 = "성균관대학교 "
str2 = "파이썬"
result = str1 + str2
print(result)
# Out:
# 성균관대학교 파이썬

# %%
num1 = int(input("숫자1 ==>"))
num2 = int(input("숫자2 ==>"))

result1 = num1 + num2
result2 = num1 - num2
result3 = num1 * num2
result4 = num1 / num2
result5 = num1 % num2 #나머지 연산
result6 = num1 ** num2

print(num1, "+", num2, "=", result1)
print(num1, "-", num2, "=", result2)
print(num1, "*", num2, "=", result3)
print(num1, "/", num2, "=", result4)
print(num1, "%", num2, "=", result5)
print(num1, "**", num2, "=", result6)
# Out:
# 숫자1 ==>8
# 숫자2 ==>3
# 8 + 3 = 11
# 8 - 3 = 5
# 8 * 3 = 24
# 8 / 3 = 2.6666666666666665
# 8 % 3 = 2
# 8 ** 3 = 512

# %%
#1
print('## 택배를 보내기 위한 정보를 입력하세요. ##')

personName = input('받는 사람 : ')
personAddr = input('주소 : ')
weight = int(input('무게(g) : '))

#2
print('** 받는 사람 ==>', personName)
print('** 주소 ==>', personAddr)

#3
print('** 배송비 ==>', weight * 50)
# Out:
# ## 택배를 보내기 위한 정보를 입력하세요. ##
# 받는 사람 : 성균관대학교
# 주소 : 명륜동
# 무게(g) : 50
# ** 받는 사람 ==> 성균관대학교
# ** 주소 ==> 명륜동
# ** 배송비 ==> 2500

# %%
#변수의 동시 선언
a = b = c = 1
print(a, b, c)

d, e, f = 3, 4, 5
print(d, e, f)
# Out:
# 1 1 1
# 3 4 5

# %%
q = 5 // 3 #몫
r = 5 % 3 #나머지
print(q, r)

num = 5 ** 3
print(num)
# Out:
# 1 2
# 125

# %%
num1 = int(input("나눠지는 수 == "))
num2 = int(input("나누는 수 ÷ ==> "))
q = num1 // num2
r = num1 % num2

print(num1, '을(를)', num2, '(으)로 나눈 몫은 ', q, '입니다.')
print(num1, '을(를)', num2, '(으)로 나눈 나머지는 ', r, '입니다.')
# Out:
# 나눠지는 수 == 545
# 나누는 수 ÷ ==> 23
# 545 을(를) 23 (으)로 나눈 몫은  23 입니다.
# 545 을(를) 23 (으)로 나눈 나머지는  16 입니다.

# %%
#1
pound = int(input("파운드(lb)를 입력하세요 : "))
kg = pound * 0.453592
print(pound, "파운드(lb)", kg," 킬로그램(kg) 입니다.")

#2
kg = int(input("킬로그램(kg)을 입력하세요: "))
pound = kg * 2.204623
print( kg, "(kg)", pound," 파운드(lb) 입니다.")
# Out:
# 파운드(lb)를 입력하세요 : 50
# 50 파운드(lb) 22.6796  킬로그램(kg) 입니다.
# 킬로그램(kg)을 입력하세요: 30
# 30 (kg) 66.13869000000001  파운드(lb) 입니다.

# %%
num = 100
num = 100 * 200
num = int("100") + int("200")
print(num)
# Out:
# 300

# %%
num1, num2 = 100, 200
num1, num2 = 100*200, 100+200
num1, num2 = int("100"), 100//5
num1, num2
# Out:
# (100, 20)

# %%
num = 20
num += 3 ; print(num)
num -= 3 ; print(num)
num *= 3 ; print(num)
num /= 3 ; print(num)
num //= 3 ; print(num)
num %= 3 ; print(num)
num **= 3 ; print(num)
# Out:
# 23
# 20
# 60
# 20.0
# 6.0
# 0.0
# 0.0

# %%
#1
total = 0

#2
total -= 900 * 10
print(total)
total -= 3500 * 5
print(total)

#3
total += 1800*2
print(total)
total += 4000 * 4
print(total)
total += 1500
print(total)
total += 2000 * 4
print(total)
total += 1800 * 5
print(total)

#4
print('오늘 총 매출액은 ', total, '원 입니다.')
# Out:
# -9000
# -26500
# -22900
# -6900
# -5400
# 2600
# 11600
# 오늘 총 매출액은  11600 원 입니다.

# %%
score = int(input('필기 시험점수를 입력하세요 ==>'))
print(score >= 70)
# Out:
# 필기 시험점수를 입력하세요 ==>80
# True

# %%
n1 = 100
n2 = 200
print(n1 == n2, n1 != n2)
print(n1 > n2, n1 < n2)
print(n1 >= n2, n1 <= n1)
# Out:
# False True
# False True
# False True

# %%
#학점
python = 3
mobile = 2
excel = 1

A =4.5
A0 = 4.0
B = 3.5

avg = ((python * B) + (mobile * A0) + (excel * A)) / (python + mobile + excel)
print('평균 학점 : ', avg)
# Out:
# 평균 학점 :  3.8333333333333335

# %% [markdown]
# # 주석

# %%
"""
이것은 주석 첫줄
이것은 주석 둘째줄
"""
# Out:
# '\n이것은 주석 첫줄\n이것은 주석 둘째줄\n'

# %%
print("\n줄바꿈\n연습")
print("어떤 글자를 \"강조\"하는 효과1")
print("어떤 글자를 \"강조\"하는 효과2")
print("\\\\백슬래시 2개 출력")
# Out:
# 줄바꿈
# 연습
# 어떤 글자를 "강조"하는 효과1
# 어떤 글자를 "강조"하는 효과2
# \\백슬래시 2개 출력

# %% [markdown]
# # 문자열 처리 함수

# %%
var1 = "대한민국처음! Python"
len(var1)
# Out:
# 14

# %%
var1 = input("첫번째 문자열 ==>")
var2 = input("두번째 문자열 ==>")

len1 = len(var1)
len2 = len(var2)

diff = len1 - len2

print("두 문자열의 길이 차이는", diff, "입니다.")
# Out:
# 첫번째 문자열 ==>성균관대학교
# 두번째 문자열 ==>인공지능
# 두 문자열의 길이 차이는 2 입니다.

# %%
ss = "First Python을 밤 12시까지 열공 중!"
var1 = ss.upper()
print(var1)
var2 = ss.lower()
print(var2)
# Out:
# FIRST PYTHON을 밤 12시까지 열공 중!
# first python을 밤 12시까지 열공 중!

# %%
ss = "fisrt python"
ss.isupper()
ss.islower() #최종값만 출력
# Out:
# True

# %%
ss = "처음 파이썬을 처음으로 학습 중입니다. 파이썬은 처음이지만 재미있네요, ^^"
ss.count("파이썬")
ss.count("Python")

# %%
ss = '처음 Python'
ss.find('P')
# Out:
# 3

# %%
ss = "처음 파이썬을 공부하는게 처음이네요."
ss.find("처음")
# Out:
# 0

# %%
ss.find("공부")
# Out:
# 8

# %%
ss.find("처음", 4)
# Out:
# 14

# %%
ss = "Python"
len(ss)
# Out:
# 6

# %%
print(ss[3])
print(ss[4])
# Out:
# h
# o

# %%
#1
ss = "성균관대학교"
print("원본 문자열 ==>", ss)

#2
print("반대 문자열 ==>", end='')

#3
print(ss[5], end='')
print(ss[4], end='')
print(ss[3], end='')
print(ss[2], end='')
print(ss[1], end='')
print(ss[0], end='')
# Out:
# 원본 문자열 ==> 성균관대학교
# 반대 문자열 ==>교학대관균성

# %%
ss = "Python"
print("원본 문자열 ==>", ss)
ss2 = ""
# Out:
# 원본 문자열 ==> Python

# %%
ss2 += ss[0].lower()
ss2
# Out:
# 'p'

# %%
ss2 += ss[1].upper()
ss2 += ss[2].upper()
ss2 += ss[3].upper()
ss2 += ss[4].upper()
ss2 += ss[5].upper()
print("변환 문자열 ==>", end="")
print(ss2)
# Out:
# 변환 문자열 ==>pYTHON

# %%
print(float(2.54))
print(round(2.54))
print(round(2.54, 1))
print(round(123556, -2))
print(round(123556, -1))
print(round(123546, -2))
# Out:
# 2.54
# 3
# 2.5
# 123600
# 123560
# 123500

# %%
print(10 + float("314e2"))
print(10 + float("314e-1"))
print(10 + float("314e-2"))
print(10 + float("314e-3"))
print(10 + float("1014e-3"))
# Out:
# 31410.0
# 41.4
# 13.14
# 10.314
# 11.014
