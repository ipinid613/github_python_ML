# %% [markdown]
# # 사용자 정의 함수

# %%
userName = 'Hong gil dong'

print('이름 : ', userName)
print('이름의 길이 : ',len(userName))
# Out:
# 이름 :  Hong gil dong
# 이름의 길이 :  13

# %%
def startTemperatureSensor():
    print('온도센서 작동을 시작한다.')

def stopTemperatureSensor():
    print('온도센서 작동을 중지한다.')

startTemperatureSensor()
stopTemperatureSensor()
# Out:
# 온도센서 작동을 시작한다.
# 온도센서 작동을 중지한다.

# %%
def greet():
    print('Hello.')
    print('Nice to meet you.')

greet()
greet()
greet()
# Out:
# Hello.
# Nice to meet you.
# Hello.
# Nice to meet you.
# Hello.
# Nice to meet you.

# %%
def convertUnit():
    print(lengthCm, 'cm = ', lengthCm * 0.393701, 'inch')

lengthCm = float(input('길이를 입력하세요.(cm)'))
convertUnit()
# Out:
# 길이를 입력하세요.(cm)183
# 183.0 cm =  72.04728300000001 inch

# %%
def calculateDistance():
    print('이동 거리는', hourData * speedData, 'km 입니다.')

hourData = float(input('이동 시간을 입력하세요. '))
speedData = float(input('이동 속도를 입력하세요. '))
calculateDistance()
# Out:
# 이동 시간을 입력하세요. 3
# 이동 속도를 입력하세요. 86
# 이동 거리는 258.0 km 입니다.

# %%
def getMemberInDatabase():
    pass

def sendMemberIdByEmail():
    pass

m_name = input('이름을 입력하세요. ')
m_mail = input('메일 주소를 입력하세요. ')

getMemberInDatabase()
sendMemberIdByEmail()
# Out:
# 이름을 입력하세요. 홍길동
# 메일 주소를 입력하세요. gildong@naver.com

# %%
def addCalculator():
    print('첫 번째 숫자와 두 번째 숫자의 합은', num1 + num2, '입니다.')

num1 = int(input('첫 번째 숫자를 입력하세요. '))
num2 = int(input('두 번째 숫자를 입력하세요. '))

addCalculator()
# Out:
# 첫 번째 숫자를 입력하세요. 5
# 두 번째 숫자를 입력하세요. 9
# 첫 번째 숫자와 두 번째 숫자의 합은 14 입니다.

# %%
def fun1():
    print('fun1 함수를 호출합니다!')

def fun2():
    print('fun2 함수를 호출합니다!')

def fun3():
    fun1()
    fun2()
    print('fun3 함수를 호출합니다!')

fun3()
# Out:
# fun1 함수를 호출합니다!
# fun2 함수를 호출합니다!
# fun3 함수를 호출합니다!

# %%
def introKor():
    print('안녕')

def introEng():
    print('Hello')

def introJap():
    print('일본어 안녕')

selectNum = int(input('where are you from? 1. 한국, 2. USA, 3. 일본'))

if selectNum == 1:
    introKor()
elif selectNum == 2:
    introEng()
elif selectNum == 3:
    introJap()
else:
    introEng()
# Out:
# where are you from? 1. 한국, 2. USA, 3. 일본3
# 일본어 안녕

# %%
def add():
    print('덧셈 결과 : ', inputNumber1 + inputNumber2)

def sub():
    print('뺄셈 결과 : ', inputNumber1 - inputNumber2)

def mul():
    print('곱셈 결과 : ', inputNumber1 * inputNumber2)

def div():
    print('나눗셈 결과 : ', inputNumber1 / inputNumber2)

def calculator():
    if selectOperator == 1:
        add()
    elif selectOperator == 2:
        sub()
    elif selectOperator == 3:
        mul()
    elif selectOperator == 4:
        div()

inputNumber1 = float(input('숫자를 입력하세요. '))
selectOperator = int(input('연산자를 선택하세요. 1.덧셈, 2.뺄셈, 3.곱셈, 4.나눗셈'))
inputNumber2 = float(input('숫자를 입력하세요.'))

calculator()
# Out:
# 숫자를 입력하세요. 12
# 연산자를 선택하세요. 1.덧셈, 2.뺄셈, 3.곱셈, 4.나눗셈3
# 숫자를 입력하세요.3
# 곱셈 결과 :  36.0
